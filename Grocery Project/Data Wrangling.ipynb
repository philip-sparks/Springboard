# %% [markdown]
# # Instacart Market Basket Analysis Data Wrangling
#
# ### By Philip Sparks

# %%
# Import the neccessary modules for data manipulation and visual representation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as matplot
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### From GitHub, these descriptions will help with wrangling the data into the correct format for discovery and analysis.
#
# `orders` (3.4m rows, 206k users):
# * `order_id`: order identifier
# * `user_id`: customer identifier
# * `eval_set`: which evaluation set this order belongs in (see `SET` described below)
# * `order_number`: the order sequence number for this user (1 = first, n = nth)
# * `order_dow`: the day of the week the order was placed on
# * `order_hour_of_day`: the hour of the day the order was placed on
# * `days_since_prior`: days since the last order, capped at 30 (with NAs for `order_number` = 1)
#
# `products` (50k rows):
# * `product_id`: product identifier
# * `product_name`: name of the product
# * `aisle_id`: foreign key
# * `department_id`: foreign key
#
# `aisles` (134 rows):
# * `aisle_id`: aisle identifier
# * `aisle`: the name of the aisle
#
# `deptartments` (21 rows):
# * `department_id`: department identifier
# * `department`: the name of the department
#
# `order_products__SET` (30m+ rows):
# * `order_id`: foreign key
# * `product_id`: foreign key
# * `add_to_cart_order`: order in which each product was added to cart
# * `reordered`: 1 if this product has been ordered by this user in the past, 0 otherwise
#
# where `SET` is one of the four following evaluation sets (`eval_set` in `orders`):
# * `"prior"`: orders prior to that users most recent order (~3.2m orders)
# * `"train"`: training data supplied to participants (~131k orders)
# * `"test"`: test data reserved for machine learning competitions (~75k orders)

# %% [markdown]
# ### Convert all tables to the Pandas Data Frames we will eventually be working with.

# %%
aisles = pd.DataFrame.from_csv('instacart_2017_05_01/aisles.csv')

departments = pd.DataFrame.from_csv('instacart_2017_05_01/departments.csv')

order_products__priors = pd.DataFrame.from_csv('instacart_2017_05_01/order_products__prior.csv')

order_products__train = pd.DataFrame.from_csv('instacart_2017_05_01/order_products__train.csv')

orders = pd.DataFrame.from_csv('instacart_2017_05_01/orders.csv')

products = pd.DataFrame.from_csv('instacart_2017_05_01/products.csv')

# %% [markdown]
# ### Check the heads of the data to see samples and confirm data is loaded.

# %%
aisles.head()
# Out:
#                                aisle
# aisle_id
# 1              prepared soups salads
# 2                  specialty cheeses
# 3                energy granola bars
# 4                      instant foods
# 5         marinades meat preparation

# %%
departments.head()
# Out:
#               department
# department_id
# 1                 frozen
# 2                  other
# 3                 bakery
# 4                produce
# 5                alcohol

# %%
order_products__priors.head(10)
# Out:
#           product_id  add_to_cart_order  reordered
# order_id
# 2              33120                  1          1
# 2              28985                  2          1
# 2               9327                  3          0
# 2              45918                  4          1
# 2              30035                  5          0
# 2              17794                  6          1
# 2              40141                  7          1
# 2               1819                  8          1
# 2              43668                  9          0
# 3              33754                  1          1

# %%
order_products__train.head(10)
# Out:
#           product_id  add_to_cart_order  reordered
# order_id
# 1              49302                  1          1
# 1              11109                  2          1
# 1              10246                  3          0
# 1              49683                  4          0
# 1              43633                  5          1
# 1              13176                  6          0
# 1              47209                  7          0
# 1              22035                  8          1
# 36             39612                  1          0
# 36             19660                  2          1

# %%
orders.sort_index().head()
# Out:
#           user_id eval_set  order_number  order_dow  order_hour_of_day  \
# order_id
# 1          112108    train             4          4                 10
# 2          202279    prior             3          5                  9
# 3          205970    prior            16          5                 17
# 4          178520    prior            36          1                  9
# 5          156122    prior            42          6                 16
#
#           days_since_prior_order
# order_id
# 1                            9.0
# 2                            8.0
# 3                           12.0
# 4                            7.0
# 5                            9.0

# %%
products.head(10)
# Out:
#                                                  product_name  aisle_id  \
# product_id
# 1                                  Chocolate Sandwich Cookies        61
# 2                                            All-Seasons Salt       104
# 3                        Robust Golden Unsweetened Oolong Tea        94
# 4           Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 5                                   Green Chile Anytime Sauce         5
# 6                                                Dry Nose Oil        11
# 7                              Pure Coconut Water With Orange        98
# 8                           Cut Russet Potatoes Steam N' Mash       116
# 9                           Light Strawberry Blueberry Yogurt       120
# 10             Sparkling Orange Juice & Prickly Pear Beverage       115
#
#             department_id
# product_id
# 1                      19
# 2                      13
# 3                       7
# 4                       1
# 5                      13
# 6                      11
# 7                       7
# 8                       1
# 9                      16
# 10                      7

# %% [markdown]
# ### Check for null values.

# %%
print aisles.isnull().any()
print departments.isnull().any()
print orders.isnull().any()
print products.isnull().any()
# Out:
# aisle    False
# dtype: bool
# department    False
# dtype: bool
# user_id                   False
# eval_set                  False
# order_number              False
# order_dow                 False
# order_hour_of_day         False
# days_since_prior_order     True
# dtype: bool
# product_name     False
# aisle_id         False
# department_id    False
# dtype: bool

# %% [markdown]
# ### Determine the same with the product orders.

# %%
print order_products__priors.isnull().any()
print order_products__train.isnull().any()
# Out:
# product_id           False
# add_to_cart_order    False
# reordered            False
# dtype: bool
# product_id           False
# add_to_cart_order    False
# reordered            False
# dtype: bool

# %% [markdown]
# ### orders : days_since_prior_order has NaN. We'll change that to "0" to have numerical values throughout the set.

# %%
orders.fillna(value = 0).head(5)
# Out:
#           user_id eval_set  order_number  order_dow  order_hour_of_day  \
# order_id
# 2539329         1    prior             1          2                  8
# 2398795         1    prior             2          3                  7
# 473747          1    prior             3          3                 12
# 2254736         1    prior             4          4                  7
# 431534          1    prior             5          4                 15
#
#           days_since_prior_order
# order_id
# 2539329                      0.0
# 2398795                     15.0
# 473747                      21.0
# 2254736                     29.0
# 431534                      28.0

# %%
print orders.isnull().any()
# Out:
# user_id                   False
# eval_set                  False
# order_number              False
# order_dow                 False
# order_hour_of_day         False
# days_since_prior_order     True
# dtype: bool

# %%
#orders.describe()

# %% [markdown]
# ### Append training and prior sets to create a data frame with all rows for merging.

# %%
orders_products_full = order_products__priors.append(order_products__train)

# %%
orders.sort_index().head()
# Out:
#           user_id eval_set  order_number  order_dow  order_hour_of_day  \
# order_id
# 1          112108    train             4          4                 10
# 2          202279    prior             3          5                  9
# 3          205970    prior            16          5                 17
# 4          178520    prior            36          1                  9
# 5          156122    prior            42          6                 16
#
#           days_since_prior_order
# order_id
# 1                            9.0
# 2                            8.0
# 3                           12.0
# 4                            7.0
# 5                            9.0

# %%
orders_products_full.sort_index().head()
# Out:
#           product_id  add_to_cart_order  reordered
# order_id
# 1              49302                  1          1
# 1              10246                  3          0
# 1              49683                  4          0
# 1              43633                  5          1
# 1              13176                  6          0

# %% [markdown]
# ### Merge the data frames into one for future EDA and analysis.

# %%
orders_join_1 = pd.merge(orders, orders_products_full, left_index = True, right_index = True, how = 'left')

# %%
orders_join_1.head()
# Out:
#           user_id eval_set  order_number  order_dow  order_hour_of_day  \
# order_id
# 1          112108    train             4          4                 10
# 1          112108    train             4          4                 10
# 1          112108    train             4          4                 10
# 1          112108    train             4          4                 10
# 1          112108    train             4          4                 10
#
#           days_since_prior_order  product_id  add_to_cart_order  reordered
# order_id
# 1                            9.0     49302.0                1.0        1.0
# 1                            9.0     11109.0                2.0        1.0
# 1                            9.0     10246.0                3.0        0.0
# 1                            9.0     49683.0                4.0        0.0
# 1                            9.0     43633.0                5.0        1.0

# %%
orders_join_2 = pd.merge(orders_join_1, products, left_on = 'product_id', right_index = True, how = 'left')

# %%
orders_join_2.head(5)
# Out:
#           user_id eval_set  order_number  order_dow  order_hour_of_day  \
# order_id
# 1          112108    train             4          4                 10
# 1          112108    train             4          4                 10
# 1          112108    train             4          4                 10
# 1          112108    train             4          4                 10
# 1          112108    train             4          4                 10
#
#           days_since_prior_order product_id  add_to_cart_order  reordered  \
# order_id
# 1                            9.0      49302                1.0        1.0
# 1                            9.0      11109                2.0        1.0
# 1                            9.0      10246                3.0        0.0
# 1                            9.0      49683                4.0        0.0
# 1                            9.0      43633                5.0        1.0
#
#                                            product_name  aisle_id  \
# order_id
# 1                                      Bulgarian Yogurt     120.0
# 1         Organic 4% Milk Fat Whole Milk Cottage Cheese     108.0
# 1                                 Organic Celery Hearts      83.0
# 1                                        Cucumber Kirby      83.0
# 1                  Lightly Smoked Sardines in Olive Oil      95.0
#
#           department_id
# order_id
# 1                  16.0
# 1                  16.0
# 1                   4.0
# 1                   4.0
# 1                  15.0

# %%
aisles.head()
# Out:
#                                aisle
# aisle_id
# 1              prepared soups salads
# 2                  specialty cheeses
# 3                energy granola bars
# 4                      instant foods
# 5         marinades meat preparation

# %%
orders_final = pd.merge(orders_join_2, aisles, left_on = 'aisle_id', right_index = True, how = 'left')

# %%
orders_final
# Out:
#           user_id eval_set  order_number  order_dow  order_hour_of_day  \
# order_id
# 1          112108    train             4          4                 10
# 1          112108    train             4          4                 10
# 1          112108    train             4          4                 10
# 1          112108    train             4          4                 10
# 1          112108    train             4          4                 10
# 1          112108    train             4          4                 10
# 1          112108    train             4          4                 10
# 1          112108    train             4          4                 10
# 2          202279    prior             3          5                  9
# 2          202279    prior             3          5                  9
# 2          202279    prior             3          5                  9
# 2          202279    prior             3          5                  9
# 2          202279    prior             3          5                  9
# 2          202279    prior             3          5                  9
# 2          202279    prior             3          5                  9
# 2          202279    prior             3          5                  9
# 2          202279    prior             3          5                  9
# 3          205970    prior            16          5                 17
# 3          205970    prior            16          5                 17
# 3          205970    prior            16          5                 17
# 3          205970    prior            16          5                 17
# 3          205970    prior            16          5                 17
# 3          205970    prior            16          5                 17
# 3          205970    prior            16          5                 17
# 3          205970    prior            16          5                 17
# 4          178520    prior            36          1                  9
# 4          178520    prior            36          1                  9
# 4          178520    prior            36          1                  9
# 4          178520    prior            36          1                  9
# 4          178520    prior            36          1                  9
# ...           ...      ...           ...        ...                ...
# 3421080     52726    prior             2          1                 11
# 3421080     52726    prior             2          1                 11
# 3421080     52726    prior             2          1                 11
# 3421080     52726    prior             2          1                 11
# 3421080     52726    prior             2          1                 11
# 3421080     52726    prior             2          1                 11
# 3421081    117076    prior             1          3                 11
# 3421081    117076    prior             1          3                 11
# 3421081    117076    prior             1          3                 11
# 3421081    117076    prior             1          3                 11
# 3421081    117076    prior             1          3                 11
# 3421081    117076    prior             1          3                 11
# 3421081    117076    prior             1          3                 11
# 3421082    175185    prior            23          2                 18
# 3421082    175185    prior            23          2                 18
# 3421082    175185    prior            23          2                 18
# 3421082    175185    prior            23          2                 18
# 3421082    175185    prior            23          2                 18
# 3421082    175185    prior            23          2                 18
# 3421082    175185    prior            23          2                 18
# 3421083     25247    prior            24          2                  6
# 3421083     25247    prior            24          2                  6
# 3421083     25247    prior            24          2                  6
# 3421083     25247    prior            24          2                  6
# 3421083     25247    prior            24          2                  6
# 3421083     25247    prior            24          2                  6
# 3421083     25247    prior            24          2                  6
# 3421083     25247    prior            24          2                  6
# 3421083     25247    prior            24          2                  6
# 3421083     25247    prior            24          2                  6
#
#           days_since_prior_order product_id  add_to_cart_order  reordered  \
# order_id
# 1                            9.0      49302                1.0        1.0
# 1                            9.0      11109                2.0        1.0
# 1                            9.0      10246                3.0        0.0
# 1                            9.0      49683                4.0        0.0
# 1                            9.0      43633                5.0        1.0
# 1                            9.0      13176                6.0        0.0
# 1                            9.0      47209                7.0        0.0
# 1                            9.0      22035                8.0        1.0
# 2                            8.0      33120                1.0        1.0
# 2                            8.0      28985                2.0        1.0
# 2                            8.0       9327                3.0        0.0
# 2                            8.0      45918                4.0        1.0
# 2                            8.0      30035                5.0        0.0
# 2                            8.0      17794                6.0        1.0
# 2                            8.0      40141                7.0        1.0
# 2                            8.0       1819                8.0        1.0
# 2                            8.0      43668                9.0        0.0
# 3                           12.0      33754                1.0        1.0
# 3                           12.0      24838                2.0        1.0
# 3                           12.0      17704                3.0        1.0
# 3                           12.0      21903                4.0        1.0
# 3                           12.0      17668                5.0        1.0
# 3                           12.0      46667                6.0        1.0
# 3                           12.0      17461                7.0        1.0
# 3                           12.0      32665                8.0        1.0
# 4                            7.0      46842                1.0        0.0
# 4                            7.0      26434                2.0        1.0
# 4                            7.0      39758                3.0        1.0
# 4                            7.0      27761                4.0        1.0
# 4                            7.0      10054                5.0        1.0
# ...                          ...        ...                ...        ...
# 3421080                      2.0      41950                4.0        0.0
# 3421080                      2.0      31717                5.0        0.0
# 3421080                      2.0      12935                6.0        1.0
# 3421080                      2.0      25122                7.0        0.0
# 3421080                      2.0      10667                8.0        0.0
# 3421080                      2.0      38061                9.0        0.0
# 3421081                      NaN      38185                1.0        0.0
# 3421081                      NaN      12218                2.0        0.0
# 3421081                      NaN      32299                3.0        0.0
# 3421081                      NaN       3060                4.0        0.0
# 3421081                      NaN      20539                5.0        0.0
# 3421081                      NaN      35221                6.0        0.0
# 3421081                      NaN      12861                7.0        0.0
# 3421082                      4.0      17279                1.0        1.0
# 3421082                      4.0      12738                2.0        1.0
# 3421082                      4.0      16797                3.0        0.0
# 3421082                      4.0      43352                4.0        1.0
# 3421082                      4.0      32700                5.0        1.0
# 3421082                      4.0      12023                6.0        0.0
# 3421082                      4.0      47941                7.0        0.0
# 3421083                     21.0       7854                1.0        0.0
# 3421083                     21.0      45309                2.0        0.0
# 3421083                     21.0      21162                3.0        0.0
# 3421083                     21.0      18176                4.0        1.0
# 3421083                     21.0      35211                5.0        0.0
# 3421083                     21.0      39678                6.0        1.0
# 3421083                     21.0      11352                7.0        0.0
# 3421083                     21.0       4600                8.0        0.0
# 3421083                     21.0      24852                9.0        1.0
# 3421083                     21.0       5020               10.0        1.0
#
#                                                product_name aisle_id  \
# order_id
# 1                                          Bulgarian Yogurt      120
# 1             Organic 4% Milk Fat Whole Milk Cottage Cheese      108
# 1                                     Organic Celery Hearts       83
# 1                                            Cucumber Kirby       83
# 1                      Lightly Smoked Sardines in Olive Oil       95
# 1                                    Bag of Organic Bananas       24
# 1                                      Organic Hass Avocado       24
# 1                               Organic Whole String Cheese       21
# 2                                        Organic Egg Whites       86
# 2                                     Michigan Organic Kale       83
# 2                                             Garlic Powder      104
# 2                                            Coconut Butter       19
# 2                                         Natural Sweetener       17
# 2                                                   Carrots       83
# 2                          Original Unflavored Gelatine Mix      105
# 2                  All Natural No Stir Creamy Almond Butter       88
# 2                                   Classic Blend Cole Slaw      123
# 3         Total 2% with Strawberry Lowfat Greek Strained...      120
# 3                                    Unsweetened Almondmilk       91
# 3                                                    Lemons      123
# 3                                      Organic Baby Spinach      123
# 3           Unsweetened Chocolate Almond Breeze Almond Milk       91
# 3                                       Organic Ginger Root       83
# 3         Air Chilled Organic Boneless Skinless Chicken ...       35
# 3                  Organic Ezekiel 49 Bread Cinnamon Raisin      112
# 4                                   Plain Pre-Sliced Bagels       93
# 4                                   Honey/Lemon Cough Drops       11
# 4                Chewy 25% Low Sugar Chocolate Chip Granola        3
# 4                               Oats & Chocolate Chewy Bars       48
# 4               Kellogg's Nutri-Grain Apple Cinnamon Cereal       48
# ...                                                     ...      ...
# 3421080                              Organic Tomato Cluster       83
# 3421080                                    Organic Cilantro       16
# 3421080                   Organic Pasture Raised Brown Eggs       86
# 3421080        Organic European Style Lightly Salted Butter       36
# 3421080                                     Imported Butter       36
# 3421080                          Organic Raw Coconut Butter       36
# 3421081                Hint of Lime Flavored Tortilla Chips      107
# 3421081                                 Classic Wheat Bread      112
# 3421081                                       Dijon Mustard       72
# 3421081                           Pepper Jack Cheese Slices       21
# 3421081        Healthy Kids Chicken Alphabet Condensed Soup       69
# 3421081                                Lime Sparkling Water      115
# 3421081   Farmer’s Market Vine Ripened Tomato & Basil Hu...       67
# 3421082                        Fresh 99% Lean Ground Turkey       49
# 3421082                                      Original Spray       36
# 3421082                                        Strawberries       24
# 3421082                                         Raspberries       32
# 3421082                              Original Whipped Cream       53
# 3421082               Toasted Coconut Chips Original Recipe      117
# 3421082                        Special K Red Berries Cereal      121
# 3421083                           Freeze Dried Mango Slices      117
# 3421083                     Purple Carrot & blueberry Puffs       92
# 3421083            Organic Mixed Berry Yogurt & Fruit Snack       92
# 3421083             Organic Strawberry Yogurt & Fruit Snack       92
# 3421083        Organic Strawberry & Mango Dried Tiny Fruits       92
# 3421083           Free & Clear Natural Dishwasher Detergent       74
# 3421083        Organic Mini Sandwich Crackers Peanut Butter       78
# 3421083                     All Natural French Toast Sticks       52
# 3421083                                              Banana       24
# 3421083   Organic  Sweet & Salty Peanut Pretzel Granola ...        3
#
#           department_id                          aisle
# order_id
# 1                  16.0                         yogurt
# 1                  16.0           other creams cheeses
# 1                   4.0               fresh vegetables
# 1                   4.0               fresh vegetables
# 1                  15.0            canned meat seafood
# 1                   4.0                   fresh fruits
# 1                   4.0                   fresh fruits
# 1                  16.0                packaged cheese
# 2                  16.0                           eggs
# 2                   4.0               fresh vegetables
# 2                  13.0              spices seasonings
# 2                  13.0                  oils vinegars
# 2                  13.0             baking ingredients
# 2                   4.0               fresh vegetables
# 2                  13.0     doughs gelatins bake mixes
# 2                  13.0                        spreads
# 2                   4.0     packaged vegetables fruits
# 3                  16.0                         yogurt
# 3                  16.0                soy lactosefree
# 3                   4.0     packaged vegetables fruits
# 3                   4.0     packaged vegetables fruits
# 3                  16.0                soy lactosefree
# 3                   4.0               fresh vegetables
# 3                  12.0                poultry counter
# 3                   3.0                          bread
# 4                   3.0               breakfast bakery
# 4                  11.0               cold flu allergy
# 4                  19.0            energy granola bars
# 4                  14.0        breakfast bars pastries
# 4                  14.0        breakfast bars pastries
# ...                 ...                            ...
# 3421080             4.0               fresh vegetables
# 3421080             4.0                    fresh herbs
# 3421080            16.0                           eggs
# 3421080            16.0                         butter
# 3421080            16.0                         butter
# 3421080            16.0                         butter
# 3421081            19.0                 chips pretzels
# 3421081             3.0                          bread
# 3421081            13.0                     condiments
# 3421081            16.0                packaged cheese
# 3421081            15.0            soup broth bouillon
# 3421081             7.0  water seltzer sparkling water
# 3421081            20.0           fresh dips tapenades
# 3421082            12.0               packaged poultry
# 3421082            16.0                         butter
# 3421082             4.0                   fresh fruits
# 3421082             4.0               packaged produce
# 3421082            16.0                          cream
# 3421082            19.0         nuts seeds dried fruit
# 3421082            14.0                         cereal
# 3421083            19.0         nuts seeds dried fruit
# 3421083            18.0              baby food formula
# 3421083            18.0              baby food formula
# 3421083            18.0              baby food formula
# 3421083            18.0              baby food formula
# 3421083            17.0                dish detergents
# 3421083            19.0                       crackers
# 3421083             1.0               frozen breakfast
# 3421083             4.0                   fresh fruits
# 3421083            19.0            energy granola bars
#
# [33894106 rows x 13 columns]

# %% [markdown]
# ### Data Frames to use for EDA

# %%
aisles
departments
order_products__priors
order_products__train
orders
products
orders_final
# Out:
#           user_id eval_set  order_number  order_dow  order_hour_of_day  \
# order_id
# 1          112108    train             4          4                 10
# 1          112108    train             4          4                 10
# 1          112108    train             4          4                 10
# 1          112108    train             4          4                 10
# 1          112108    train             4          4                 10
# 1          112108    train             4          4                 10
# 1          112108    train             4          4                 10
# 1          112108    train             4          4                 10
# 2          202279    prior             3          5                  9
# 2          202279    prior             3          5                  9
# 2          202279    prior             3          5                  9
# 2          202279    prior             3          5                  9
# 2          202279    prior             3          5                  9
# 2          202279    prior             3          5                  9
# 2          202279    prior             3          5                  9
# 2          202279    prior             3          5                  9
# 2          202279    prior             3          5                  9
# 3          205970    prior            16          5                 17
# 3          205970    prior            16          5                 17
# 3          205970    prior            16          5                 17
# 3          205970    prior            16          5                 17
# 3          205970    prior            16          5                 17
# 3          205970    prior            16          5                 17
# 3          205970    prior            16          5                 17
# 3          205970    prior            16          5                 17
# 4          178520    prior            36          1                  9
# 4          178520    prior            36          1                  9
# 4          178520    prior            36          1                  9
# 4          178520    prior            36          1                  9
# 4          178520    prior            36          1                  9
# ...           ...      ...           ...        ...                ...
# 3421080     52726    prior             2          1                 11
# 3421080     52726    prior             2          1                 11
# 3421080     52726    prior             2          1                 11
# 3421080     52726    prior             2          1                 11
# 3421080     52726    prior             2          1                 11
# 3421080     52726    prior             2          1                 11
# 3421081    117076    prior             1          3                 11
# 3421081    117076    prior             1          3                 11
# 3421081    117076    prior             1          3                 11
# 3421081    117076    prior             1          3                 11
# 3421081    117076    prior             1          3                 11
# 3421081    117076    prior             1          3                 11
# 3421081    117076    prior             1          3                 11
# 3421082    175185    prior            23          2                 18
# 3421082    175185    prior            23          2                 18
# 3421082    175185    prior            23          2                 18
# 3421082    175185    prior            23          2                 18
# 3421082    175185    prior            23          2                 18
# 3421082    175185    prior            23          2                 18
# 3421082    175185    prior            23          2                 18
# 3421083     25247    prior            24          2                  6
# 3421083     25247    prior            24          2                  6
# 3421083     25247    prior            24          2                  6
# 3421083     25247    prior            24          2                  6
# 3421083     25247    prior            24          2                  6
# 3421083     25247    prior            24          2                  6
# 3421083     25247    prior            24          2                  6
# 3421083     25247    prior            24          2                  6
# 3421083     25247    prior            24          2                  6
# 3421083     25247    prior            24          2                  6
#
#           days_since_prior_order product_id  add_to_cart_order  reordered  \
# order_id
# 1                            9.0      49302                1.0        1.0
# 1                            9.0      11109                2.0        1.0
# 1                            9.0      10246                3.0        0.0
# 1                            9.0      49683                4.0        0.0
# 1                            9.0      43633                5.0        1.0
# 1                            9.0      13176                6.0        0.0
# 1                            9.0      47209                7.0        0.0
# 1                            9.0      22035                8.0        1.0
# 2                            8.0      33120                1.0        1.0
# 2                            8.0      28985                2.0        1.0
# 2                            8.0       9327                3.0        0.0
# 2                            8.0      45918                4.0        1.0
# 2                            8.0      30035                5.0        0.0
# 2                            8.0      17794                6.0        1.0
# 2                            8.0      40141                7.0        1.0
# 2                            8.0       1819                8.0        1.0
# 2                            8.0      43668                9.0        0.0
# 3                           12.0      33754                1.0        1.0
# 3                           12.0      24838                2.0        1.0
# 3                           12.0      17704                3.0        1.0
# 3                           12.0      21903                4.0        1.0
# 3                           12.0      17668                5.0        1.0
# 3                           12.0      46667                6.0        1.0
# 3                           12.0      17461                7.0        1.0
# 3                           12.0      32665                8.0        1.0
# 4                            7.0      46842                1.0        0.0
# 4                            7.0      26434                2.0        1.0
# 4                            7.0      39758                3.0        1.0
# 4                            7.0      27761                4.0        1.0
# 4                            7.0      10054                5.0        1.0
# ...                          ...        ...                ...        ...
# 3421080                      2.0      41950                4.0        0.0
# 3421080                      2.0      31717                5.0        0.0
# 3421080                      2.0      12935                6.0        1.0
# 3421080                      2.0      25122                7.0        0.0
# 3421080                      2.0      10667                8.0        0.0
# 3421080                      2.0      38061                9.0        0.0
# 3421081                      NaN      38185                1.0        0.0
# 3421081                      NaN      12218                2.0        0.0
# 3421081                      NaN      32299                3.0        0.0
# 3421081                      NaN       3060                4.0        0.0
# 3421081                      NaN      20539                5.0        0.0
# 3421081                      NaN      35221                6.0        0.0
# 3421081                      NaN      12861                7.0        0.0
# 3421082                      4.0      17279                1.0        1.0
# 3421082                      4.0      12738                2.0        1.0
# 3421082                      4.0      16797                3.0        0.0
# 3421082                      4.0      43352                4.0        1.0
# 3421082                      4.0      32700                5.0        1.0
# 3421082                      4.0      12023                6.0        0.0
# 3421082                      4.0      47941                7.0        0.0
# 3421083                     21.0       7854                1.0        0.0
# 3421083                     21.0      45309                2.0        0.0
# 3421083                     21.0      21162                3.0        0.0
# 3421083                     21.0      18176                4.0        1.0
# 3421083                     21.0      35211                5.0        0.0
# 3421083                     21.0      39678                6.0        1.0
# 3421083                     21.0      11352                7.0        0.0
# 3421083                     21.0       4600                8.0        0.0
# 3421083                     21.0      24852                9.0        1.0
# 3421083                     21.0       5020               10.0        1.0
#
#                                                product_name aisle_id  \
# order_id
# 1                                          Bulgarian Yogurt      120
# 1             Organic 4% Milk Fat Whole Milk Cottage Cheese      108
# 1                                     Organic Celery Hearts       83
# 1                                            Cucumber Kirby       83
# 1                      Lightly Smoked Sardines in Olive Oil       95
# 1                                    Bag of Organic Bananas       24
# 1                                      Organic Hass Avocado       24
# 1                               Organic Whole String Cheese       21
# 2                                        Organic Egg Whites       86
# 2                                     Michigan Organic Kale       83
# 2                                             Garlic Powder      104
# 2                                            Coconut Butter       19
# 2                                         Natural Sweetener       17
# 2                                                   Carrots       83
# 2                          Original Unflavored Gelatine Mix      105
# 2                  All Natural No Stir Creamy Almond Butter       88
# 2                                   Classic Blend Cole Slaw      123
# 3         Total 2% with Strawberry Lowfat Greek Strained...      120
# 3                                    Unsweetened Almondmilk       91
# 3                                                    Lemons      123
# 3                                      Organic Baby Spinach      123
# 3           Unsweetened Chocolate Almond Breeze Almond Milk       91
# 3                                       Organic Ginger Root       83
# 3         Air Chilled Organic Boneless Skinless Chicken ...       35
# 3                  Organic Ezekiel 49 Bread Cinnamon Raisin      112
# 4                                   Plain Pre-Sliced Bagels       93
# 4                                   Honey/Lemon Cough Drops       11
# 4                Chewy 25% Low Sugar Chocolate Chip Granola        3
# 4                               Oats & Chocolate Chewy Bars       48
# 4               Kellogg's Nutri-Grain Apple Cinnamon Cereal       48
# ...                                                     ...      ...
# 3421080                              Organic Tomato Cluster       83
# 3421080                                    Organic Cilantro       16
# 3421080                   Organic Pasture Raised Brown Eggs       86
# 3421080        Organic European Style Lightly Salted Butter       36
# 3421080                                     Imported Butter       36
# 3421080                          Organic Raw Coconut Butter       36
# 3421081                Hint of Lime Flavored Tortilla Chips      107
# 3421081                                 Classic Wheat Bread      112
# 3421081                                       Dijon Mustard       72
# 3421081                           Pepper Jack Cheese Slices       21
# 3421081        Healthy Kids Chicken Alphabet Condensed Soup       69
# 3421081                                Lime Sparkling Water      115
# 3421081   Farmer’s Market Vine Ripened Tomato & Basil Hu...       67
# 3421082                        Fresh 99% Lean Ground Turkey       49
# 3421082                                      Original Spray       36
# 3421082                                        Strawberries       24
# 3421082                                         Raspberries       32
# 3421082                              Original Whipped Cream       53
# 3421082               Toasted Coconut Chips Original Recipe      117
# 3421082                        Special K Red Berries Cereal      121
# 3421083                           Freeze Dried Mango Slices      117
# 3421083                     Purple Carrot & blueberry Puffs       92
# 3421083            Organic Mixed Berry Yogurt & Fruit Snack       92
# 3421083             Organic Strawberry Yogurt & Fruit Snack       92
# 3421083        Organic Strawberry & Mango Dried Tiny Fruits       92
# 3421083           Free & Clear Natural Dishwasher Detergent       74
# 3421083        Organic Mini Sandwich Crackers Peanut Butter       78
# 3421083                     All Natural French Toast Sticks       52
# 3421083                                              Banana       24
# 3421083   Organic  Sweet & Salty Peanut Pretzel Granola ...        3
#
#           department_id                          aisle
# order_id
# 1                  16.0                         yogurt
# 1                  16.0           other creams cheeses
# 1                   4.0               fresh vegetables
# 1                   4.0               fresh vegetables
# 1                  15.0            canned meat seafood
# 1                   4.0                   fresh fruits
# 1                   4.0                   fresh fruits
# 1                  16.0                packaged cheese
# 2                  16.0                           eggs
# 2                   4.0               fresh vegetables
# 2                  13.0              spices seasonings
# 2                  13.0                  oils vinegars
# 2                  13.0             baking ingredients
# 2                   4.0               fresh vegetables
# 2                  13.0     doughs gelatins bake mixes
# 2                  13.0                        spreads
# 2                   4.0     packaged vegetables fruits
# 3                  16.0                         yogurt
# 3                  16.0                soy lactosefree
# 3                   4.0     packaged vegetables fruits
# 3                   4.0     packaged vegetables fruits
# 3                  16.0                soy lactosefree
# 3                   4.0               fresh vegetables
# 3                  12.0                poultry counter
# 3                   3.0                          bread
# 4                   3.0               breakfast bakery
# 4                  11.0               cold flu allergy
# 4                  19.0            energy granola bars
# 4                  14.0        breakfast bars pastries
# 4                  14.0        breakfast bars pastries
# ...                 ...                            ...
# 3421080             4.0               fresh vegetables
# 3421080             4.0                    fresh herbs
# 3421080            16.0                           eggs
# 3421080            16.0                         butter
# 3421080            16.0                         butter
# 3421080            16.0                         butter
# 3421081            19.0                 chips pretzels
# 3421081             3.0                          bread
# 3421081            13.0                     condiments
# 3421081            16.0                packaged cheese
# 3421081            15.0            soup broth bouillon
# 3421081             7.0  water seltzer sparkling water
# 3421081            20.0           fresh dips tapenades
# 3421082            12.0               packaged poultry
# 3421082            16.0                         butter
# 3421082             4.0                   fresh fruits
# 3421082             4.0               packaged produce
# 3421082            16.0                          cream
# 3421082            19.0         nuts seeds dried fruit
# 3421082            14.0                         cereal
# 3421083            19.0         nuts seeds dried fruit
# 3421083            18.0              baby food formula
# 3421083            18.0              baby food formula
# 3421083            18.0              baby food formula
# 3421083            18.0              baby food formula
# 3421083            17.0                dish detergents
# 3421083            19.0                       crackers
# 3421083             1.0               frozen breakfast
# 3421083             4.0                   fresh fruits
# 3421083            19.0            energy granola bars
#
# [33894106 rows x 13 columns]
